# %%
import pandas as pd

# %%
import pyodbc 
cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=LAPTOP-D0942MUC\SQLEXPRESS;"
                      "Database=college;"
                      "Trusted_Connection=yes;")

# %%
Students=pd.read_sql("SELECT * FROM Students$",cnxn)

# %%
Students.head()
# Out:
#    StudentId FirstName   LastName Gender
# 0      162.0    Elmira    Holston      F
# 1      154.0    Sierra  Van Vorst      F
# 2       28.0     Mycah    Bingham      F
# 3       54.0      Alia      Jones      F
# 4       31.0    Chanda   Fillmore      F

# %%
len(Students)
# Out:
# 280

# %%
Courses = pd.read_sql("SELECT * FROM Courses$",cnxn)

# %%
Courses.head()
# Out:
#    CourseId            CourseName  DepartmentID  TeacherId
# 0       1.0     English Begginers           1.0       15.0
# 1       2.0      Advanced English           1.0       15.0
# 2       3.0  Proffesional English           1.0       15.0
# 3       4.0       Mathematics 101           2.0        2.0
# 4       5.0   Matematics Advanced           2.0       13.0

# %%
len(Courses)
# Out:
# 31

# %%
Classrooms = pd.read_sql("SELECT * FROM Classrooms$",cnxn)

# %%
Classrooms.head()
# Out:
#    CourseId  StudentId     degree
# 0       1.0      202.0  92.031070
# 1       1.0       12.0  81.175916
# 2       1.0      232.0  82.396587
# 3       1.0      123.0  62.420449
# 4       1.0      274.0  72.569900

# %%
len(Classrooms)
# Out:
# 754

# %%
Departments = pd.read_sql("SELECT * FROM Departments$",cnxn)

# %%
Departments.head()
# Out:
#    DepartmentId DepartmentName
# 0           1.0        English
# 1           2.0        Science
# 2           3.0           Arts
# 3           4.0          Sport

# %%
len(Departments)
# Out:
# 4

# %%
Teachers = pd.read_sql("SELECT * FROM Teachers$",cnxn)

# %%
Teachers.head()
# Out:
#    TeacherId   FirstName  LastName Gender
# 0        1.0      Kaylea  Monzingo      F
# 1        2.0      Amanda   Dworkin      F
# 2        3.0      Jordyn     Baron      F
# 3        4.0   Katherine    Dibari      F
# 4        5.0     Heather   Metcalf      F

# %%
class_students = pd.merge(Classrooms,Students,how='inner',on='StudentId')

# %%
class_students.head()
# Out:
#    CourseId  StudentId     degree FirstName LastName Gender
# 0       1.0      202.0  92.031070    Autumn    Major      F
# 1       4.0      202.0  73.387328    Autumn    Major      F
# 2       8.0      202.0  83.563932    Autumn    Major      F
# 3      18.0      202.0  66.109849    Autumn    Major      F
# 4      20.0      202.0  63.988269    Autumn    Major      F

# %%
class_courses = pd.merge(Classrooms,Courses,how='left',on='CourseId')

# %%
len(class_courses)
# Out:
# 754

# %%
class_courses.head()
# Out:
#    CourseId  StudentId     degree         CourseName  DepartmentID  TeacherId
# 0       1.0      202.0  92.031070  English Begginers           1.0       15.0
# 1       1.0       12.0  81.175916  English Begginers           1.0       15.0
# 2       1.0      232.0  82.396587  English Begginers           1.0       15.0
# 3       1.0      123.0  62.420449  English Begginers           1.0       15.0
# 4       1.0      274.0  72.569900  English Begginers           1.0       15.0

# %%
teacher_courses = pd.merge(Teachers,Courses,how='inner',on='TeacherId')

# %%
teacher_courses.head()
# Out:
#    TeacherId   FirstName  LastName Gender  CourseId        CourseName  \
# 0        1.0      Kaylea  Monzingo      F      14.0  Computer Science
# 1        2.0      Amanda   Dworkin      F       4.0   Mathematics 101
# 2        3.0      Jordyn     Baron      F      10.0           Biology
# 3        4.0   Katherine    Dibari      F      26.0        Basketball
# 4        5.0     Heather   Metcalf      F      13.0        Statistics
#
#    DepartmentID
# 0           2.0
# 1           2.0
# 2           2.0
# 3           4.0
# 4           2.0

# %%
len(teacher_courses)
# Out:
# 31

# %%
cls_crs_dep = pd.merge(Departments,class_courses,how = 'left',left_on = 'DepartmentId',right_on = 'DepartmentID')

# %%
cls_crs_dep.head()
# Out:
#    DepartmentId DepartmentName  CourseId  StudentId     degree  \
# 0           1.0        English       1.0      202.0  92.031070
# 1           1.0        English       1.0       12.0  81.175916
# 2           1.0        English       1.0      232.0  82.396587
# 3           1.0        English       1.0      123.0  62.420449
# 4           1.0        English       1.0      274.0  72.569900
#
#           CourseName  DepartmentID  TeacherId
# 0  English Begginers           1.0       15.0
# 1  English Begginers           1.0       15.0
# 2  English Begginers           1.0       15.0
# 3  English Begginers           1.0       15.0
# 4  English Begginers           1.0       15.0

# %%
len(cls_crs_dep)
# Out:
# 754

# %% [markdown]
# #### a.	מנהל המכללה ביקש לדעת כמה סטודנטים יש לפי יחידה (מחלקה).

# %%
a = cls_crs_dep.groupby(['DepartmentName']).StudentId.nunique()
a= a.reset_index()
a.columns = ['Department Name','Students']
a
# Out:
#   Department Name  Students
# 0            Arts       137
# 1         English        84
# 2         Science       200
# 3           Sport        81

# %% [markdown]
# #### b.	המורה באנגלית צריך להתארגן וביקש לדעת כמה סטודנטים יש לו לפי כל קורס שהוא מעביר וסה"כ התלמידים בכל הקורסים שלו.

# %%
teach_crs_cls = pd.merge(Classrooms,teacher_courses,how='inner',on = 'CourseId')

# %%
teach_crs_cls.head()
# Out:
#    CourseId  StudentId     degree  TeacherId FirstName    LastName Gender  \
# 0       1.0      202.0  92.031070       15.0     Conor  Mckittrick      M
# 1       1.0       12.0  81.175916       15.0     Conor  Mckittrick      M
# 2       1.0      232.0  82.396587       15.0     Conor  Mckittrick      M
# 3       1.0      123.0  62.420449       15.0     Conor  Mckittrick      M
# 4       1.0      274.0  72.569900       15.0     Conor  Mckittrick      M
#
#           CourseName  DepartmentID
# 0  English Begginers           1.0
# 1  English Begginers           1.0
# 2  English Begginers           1.0
# 3  English Begginers           1.0
# 4  English Begginers           1.0

# %%
cls_crs_dep_teach = pd.merge(cls_crs_dep,Teachers,how='right',on = 'TeacherId')
cls_crs_dep_teach.head()
# Out:
#    DepartmentId DepartmentName  CourseId  StudentId     degree  \
# 0           1.0        English       1.0      202.0  92.031070
# 1           1.0        English       1.0       12.0  81.175916
# 2           1.0        English       1.0      232.0  82.396587
# 3           1.0        English       1.0      123.0  62.420449
# 4           1.0        English       1.0      274.0  72.569900
#
#           CourseName  DepartmentID  TeacherId FirstName    LastName Gender
# 0  English Begginers           1.0       15.0     Conor  Mckittrick      M
# 1  English Begginers           1.0       15.0     Conor  Mckittrick      M
# 2  English Begginers           1.0       15.0     Conor  Mckittrick      M
# 3  English Begginers           1.0       15.0     Conor  Mckittrick      M
# 4  English Begginers           1.0       15.0     Conor  Mckittrick      M

# %%
cls_crs_dep_teach_stud = pd.merge(cls_crs_dep_teach,Students,how='inner',on='StudentId')
cls_crs_dep_teach_stud.head()
data=cls_crs_dep_teach_stud.copy()
# Out:
#    DepartmentId DepartmentName  CourseId  StudentId     degree  \
# 0           1.0        English       1.0      202.0  92.031070
# 1           2.0        Science       4.0      202.0  73.387328
# 2           2.0        Science       8.0      202.0  83.563932
# 3           2.0        Science      18.0      202.0  66.109849
# 4           3.0           Arts      20.0      202.0  63.988269
#
#           CourseName  DepartmentID  TeacherId FirstName_x  LastName_x  \
# 0  English Begginers           1.0       15.0       Conor  Mckittrick
# 1    Mathematics 101           2.0        2.0      Amanda     Dworkin
# 2          Chemistry           2.0       14.0     Jeffrey      Batzel
# 3                  R           2.0       17.0      Tanner  Fitzsimons
# 4    History of Arts           3.0        8.0    Caroline     Knuesel
#
#   Gender_x FirstName_y LastName_y Gender_y
# 0        M      Autumn      Major        F
# 1        F      Autumn      Major        F
# 2        M      Autumn      Major        F
# 3        M      Autumn      Major        F
# 4        F      Autumn      Major        F

# %%
Teachers.nunique()
# Out:
# TeacherId    24
# FirstName    24
# LastName     24
# Gender        2
# dtype: int64

# %%
data.describe()
# Out:
#         StudentId   TeacherId  DepartmentId    CourseId      degree  \
# count  754.000000  754.000000    754.000000  754.000000  754.000000
# mean   139.814324   13.267905      2.376658   15.687003   78.206629
# std     82.819329    6.306459      0.860085    8.528534    8.507021
# min      1.000000    1.000000      1.000000    1.000000   49.236544
# 25%     66.000000    9.000000      2.000000   10.000000   72.769352
# 50%    141.000000   15.000000      2.000000   16.000000   78.370188
# 75%    213.000000   19.000000      3.000000   23.000000   83.672210
# max    280.000000   24.000000      4.000000   31.000000  100.000000
#
#        DepartmentID
# count    754.000000
# mean       2.376658
# std        0.860085
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000

# %%
len(teach_crs_cls.loc[teach_crs_cls.DepartmentID==1,])
# Out:
# 94

# %%
b= teach_crs_cls[teach_crs_cls.DepartmentID==1].groupby(teach_crs_cls.CourseName).StudentId.nunique()

Total=teach_crs_cls[teach_crs_cls.CourseName=='English'].groupby.sum()
print (b)
print(Total)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-c51d79ae0227> in <module>
#       1 b= teach_crs_cls[teach_crs_cls.DepartmentID==1].groupby(teach_crs_cls.CourseName).StudentId.nunique()
#       2
# ----> 3 Total=teach_crs_cls[teach_crs_cls.CourseName=='English'].groupby.sum()
#       4 print (b)
#       5 print(Total)
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
teach_crs_cls.groupby(teach_crs_cls.CourseName).StudentId.nunique()
# Out:
# 29

# %%
teach_crs_cls.sort_values(by='DepartmentID')
# Out:
#      CourseId  StudentId     degree  TeacherId FirstName    LastName Gender  \
# 0         1.0      202.0  92.031070       15.0     Conor  Mckittrick      M
# 68        3.0      222.0  81.936963       15.0     Conor  Mckittrick      M
# 67        3.0      114.0  78.084967       15.0     Conor  Mckittrick      M
# 66        3.0      204.0  83.492492       15.0     Conor  Mckittrick      M
# 65        3.0      208.0  78.568032       15.0     Conor  Mckittrick      M
# ..        ...        ...        ...        ...       ...         ...    ...
# 684      27.0      225.0  87.999460       11.0   Kaitlin      Delude      F
# 683      27.0      197.0  63.882938       11.0   Kaitlin      Delude      F
# 682      27.0       77.0  91.706066       11.0   Kaitlin      Delude      F
# 704      29.0      129.0  77.458607       24.0    Keegan       Price      M
# 753      31.0       16.0  78.507968       23.0   Maxwell      Romkee      M
#
#                CourseName  DepartmentID
# 0       English Begginers           1.0
# 68   Proffesional English           1.0
# 67   Proffesional English           1.0
# 66   Proffesional English           1.0
# 65   Proffesional English           1.0
# ..                    ...           ...
# 684            Volleyball           4.0
# 683            Volleyball           4.0
# 682            Volleyball           4.0
# 704                 Tenis           4.0
# 753            Gymnastics           4.0
#
# [754 rows x 9 columns]

# %%
teach_crs_cls.where(teach_crs_cls.TeacherId==15).groupby.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-cfd0c7cc32bb> in <module>
# ----> 1 teach_crs_cls.where(teach_crs_cls.TeacherId==15).groupby.sum()
#
# AttributeError: 'function' object has no attribute 'sum'
