# %%
import pandas as pd

# %%
import pyodbc 
cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=LAPTOP-D0942MUC\SQLEXPRESS;"
                      "Database=college;"
                      "Trusted_Connection=yes;")

# %%
Students=pd.read_sql("SELECT * FROM Students$",cnxn)
Courses = pd.read_sql("SELECT * FROM Courses$",cnxn)
Classrooms = pd.read_sql("SELECT * FROM Classrooms$",cnxn)
Departments = pd.read_sql("SELECT * FROM Departments$",cnxn)
Teachers = pd.read_sql("SELECT * FROM Teachers$",cnxn)
class_courses = pd.merge(Classrooms,Courses,how='outer',on='CourseId')
cls_crs_dep = pd.merge(Departments,class_courses,how = 'left',left_on = 'DepartmentId',right_on = 'DepartmentID')
cls_crs_dep_teach = pd.merge(cls_crs_dep,Teachers,how='inner',on = 'TeacherId')
cls_crs_dep_teach_stud = pd.merge(cls_crs_dep_teach,Students,how='outer',on='StudentId')
data=cls_crs_dep_teach_stud.copy()
data.dropna()
#data[data.CourseName=='Basketball']
#data
# Out:
#      DepartmentId DepartmentName  CourseId  StudentId     degree  \
# 0             1.0        English       1.0      202.0  92.031070
# 1             2.0        Science       4.0      202.0  73.387328
# 2             2.0        Science       8.0      202.0  83.563932
# 3             2.0        Science      18.0      202.0  66.109849
# 4             3.0           Arts      20.0      202.0  63.988269
# ..            ...            ...       ...        ...        ...
# 749           4.0          Sport      29.0      105.0  81.810113
# 750           4.0          Sport      30.0      158.0  76.336776
# 751           4.0          Sport      31.0      241.0  82.833593
# 752           4.0          Sport      31.0      262.0  78.336991
# 753           4.0          Sport      31.0      108.0  79.660333
#
#             CourseName  DepartmentID  TeacherId FirstName_x  LastName_x  \
# 0    English Begginers           1.0       15.0       Conor  Mckittrick
# 1      Mathematics 101           2.0        2.0      Amanda     Dworkin
# 2            Chemistry           2.0       14.0     Jeffrey      Batzel
# 3                    R           2.0       17.0      Tanner  Fitzsimons
# 4      History of Arts           3.0        8.0    Caroline     Knuesel
# ..                 ...           ...        ...         ...         ...
# 749              Tenis           4.0       24.0      Keegan       Price
# 750           Swimming           4.0       12.0     Mikayla     Russell
# 751         Gymnastics           4.0       23.0     Maxwell      Romkee
# 752         Gymnastics           4.0       23.0     Maxwell      Romkee
# 753         Gymnastics           4.0       23.0     Maxwell      Romkee
#
#     Gender_x FirstName_y  LastName_y Gender_y
# 0          M      Autumn       Major        F
# 1          F      Autumn       Major        F
# 2          M      Autumn       Major        F
# 3          M      Autumn       Major        F
# 4          F      Autumn       Major        F
# ..       ...         ...         ...      ...
# 749        M      Hannah      Wilkes        F
# 750        F    Mitchell   Fellhauer        M
# 751        M     Kaitlyn      Tuttle        F
# 752        M        Luke  Van Cleave        M
# 753        M       Kevin     Clifton        M
#
# [754 rows x 14 columns]

# %% [markdown]
# #### a.	מנהל המכללה ביקש לדעת כמה סטודנטים יש לפי יחידה (מחלקה).

# %%
a= data.groupby(data.DepartmentName).StudentId.nunique()
a=a.reset_index()
a.columns = ['Department Name','Students']
a
# Out:
#   Department Name  Students
# 0            Arts       137
# 1         English        84
# 2         Science       200
# 3           Sport        82

# %% [markdown]
# #### b.	המורה באנגלית צריך להתארגן וביקש לדעת כמה סטודנטים יש לו לפי כל קורס שהוא מעביר וסה"כ התלמידים בכל הקורסים שלו.

# %%
b= data[data.DepartmentID==1].groupby(data.CourseName).StudentId.nunique()
total_sum=data[data.DepartmentID==1].groupby(data.DepartmentId).nunique().iloc[0,3]

b=b.reset_index()
b.columns=['Course Name','numStudents']
print(b)
print('-----------------------')
print('Total' + "                             " + str(total_sum))

##total_sum=total_sum.reset_index()
##total_sum.columns = ['Total', 'Students']
# Out:
#             Course Name  numStudents
# 0      Advanced English           24
# 1     English Begginers           32
# 2  Proffesional English           38
# -----------------------
# Total                             84

# %% [markdown]
# #### c.	המרכז למדעים רוצה להבין כמה כיתות קטנות (מתחת ל-22) וכמה גדולות צריך עבור קורסים ביחידה (מחלקה) שלו.

# %%
c= data[data.DepartmentName=='Science'].groupby(data.CourseName).StudentId.nunique()

c=c.reset_index()
c.columns =['NumClassRooms','Students']

c.loc[c['Students']<22, 'Classize'] = 'Small'
c.loc[c ['Students']>=22 ,'Classize'] = 'Big'
Classroomsize= c.groupby(c.Classize).agg('count').iloc[:,0:1]
print(Classroomsize)
# Out:
#           NumClassRooms
# Classize
# Big                  10
# Small                 6

# %% [markdown]
# #### d.	סטודנטית שהיא פעילה פמיניסטית טוענת שהמכללה מעדיפה לקבל יותר גברים מאשר נשים. תבדקו האם הטענה מוצדקת (מבחינת כמותית, לא סטטיסטית).

# %%
d=Students.groupby(['Gender']).agg(['count']).iloc[:,0:1]
d
# Out:
#        StudentId
#            count
# Gender
# F            165
# M            115

# %% [markdown]
# #### e.	באיזה קורסים אחוז הגברים / הנשים הינה מעל 70%?

# %%
Total=data[['StudentId']].groupby(data.CourseName).agg('count')
Total

crsbygndr=data.groupby(['CourseName','CourseId','Gender_y']).StudentId.nunique()
crsbygndr.reset_index()

e=pd.merge(crsbygndr,Total,how='left',on='CourseName')
e
e['Gndr_Stud_percent']=(e['StudentId_x']/e['StudentId_y'])*100.0
e=e[e['Gndr_Stud_percent']>70]
e=e.iloc[:,2:3]
e
# Out:
#             Gndr_Stud_percent
# CourseName
# Sculpture           70.833333
# Tenis               72.222222

# %% [markdown]
# ### f.	בכל אחד מהיחידות (מחלקות), כמה סטודנטים (מספר ואחוזים) עברו עם ציון מעל 80?

# %%
Total_students=data.groupby(data.DepartmentName).StudentId.nunique()
#print(Total_students)
#data['over80']=0
#data.loc[((data.DepartmentId==1) & (data.degree>80)),'over80'] = 1
#data.loc[((data.DepartmentId==2) & (data.degree>80)),'over80'] = 1
#data.loc[((data.DepartmentId==3) & (data.degree>80)),'over80'] = 1
#data.loc[((data.DepartmentId==4) & (data.degree>80)),'over80'] = 1
#data
Students_over80=data[data.degree>80].groupby(data.DepartmentName).StudentId.nunique()
f=pd.merge(Total_students,Students_over80,how='inner',on='DepartmentName')
f['percent']=(f['StudentId_y'] / f['StudentId_x'])*100.0
f.reset_index()
f.columns=['TotalStudents','Students over80','Percentover80']
f
# Out:
#                 TotalStudents  Students over80  Percentover80
# DepartmentName
# Arts                      137               61      44.525547
# English                    84               40      47.619048
# Science                   200              122      61.000000
# Sport                      82               39      47.560976

# %% [markdown]
# ### g.	בכל אחד מהיחידות (מחלקות), כמה סטודנטים (מספר ואחוזים) לא עברו (ציון מתחת ל-60) ?

# %%
Total_students=data.groupby(data.DepartmentName).StudentId.nunique()
Students_less60=data[data.degree<60].groupby(data.DepartmentName).StudentId.nunique()
f=pd.merge(Total_students,Students_less60,how='inner',on='DepartmentName')
f['percent']=(f['StudentId_y'] / f['StudentId_x'])*100.0
f.reset_index()
f.columns=['TotalStudents','Students less60','Percentless60']
f
# Out:
#                 TotalStudents  Students less60  Percentless60
# DepartmentName
# Arts                      137                3       2.189781
# English                    84                2       2.380952
# Science                   200                7       3.500000
# Sport                      82                1       1.219512

# %% [markdown]
# ### h.	תדרגו את המורים לפי ממוצע הציון של הסטודנטים מהגבוהה לנמוך.

# %%
data['Teacher']=data['FirstName_x']+data['LastName_x']
h=data[['Teacher','degree']].groupby(['Teacher']).mean().sort_values(by='degree',ascending= False).dropna()
h
# Out:
#                       degree
# Teacher
#  DarickHess        81.432703
#  JordynBaron       80.729494
#  HeatherMetcalf    80.440242
#  ZacharyHealy      79.365867
#  KayleaMonzingo    79.365537
#  DanielBland       78.908281
#  KeeganPrice       78.814631
#  ConorMckittrick   78.699492
#  MaxwellRomkee     78.673509
#  TerranBeaty       78.495479
#  TannerFitzsimons  78.443395
#  MackenzieOlsen    78.383348
#  ErnestStoyanov    78.316150
#  MadisonBatan      77.743575
#  KaterinaYoung     77.406852
#  MikaylaRussell    77.134323
#  AmandaDworkin     76.899881
#  KaitlinDelude     76.765296
#  JeffreyBatzel     76.737973
#  RobertAivazian    76.516464
#  CarolineKnuesel   75.955453
#  AlexanderWatts    75.668139

# %% [markdown]
# ### i.	תייצרו Data Frame המראה את הקורסים, היחידות (מחלקות) עליהם משויכים, המרצה בכל קורס ומספר התלמידים רשומים בקורס

# %%
i=data.groupby(['CourseId','CourseName','DepartmentName','Teacher']).FirstName_y.nunique().reset_index()
i
#StudentId.nunique()
# Out:
#     CourseId            CourseName DepartmentName               Teacher  \
# 0        1.0     English Begginers        English       ConorMckittrick
# 1        2.0      Advanced English        English       ConorMckittrick
# 2        3.0  Proffesional English        English       ConorMckittrick
# 3        4.0       Mathematics 101        Science         AmandaDworkin
# 4        5.0   Matematics Advanced        Science        AlexanderWatts
# 5        6.0               Algebra        Science        AlexanderWatts
# 6        7.0              Geometry        Science        AlexanderWatts
# 7        8.0             Chemistry        Science         JeffreyBatzel
# 8        9.0               Physics        Science        AlexanderWatts
# 9       10.0               Biology        Science           JordynBaron
# 10      11.0              Genetics        Science           TerranBeaty
# 11      12.0          Neurobiology        Science           TerranBeaty
# 12      13.0            Statistics        Science        HeatherMetcalf
# 13      14.0      Computer Science        Science        KayleaMonzingo
# 14      15.0          Data Science        Science        MackenzieOlsen
# 15      16.0                   SQL        Science          ZacharyHealy
# 16      17.0                Python        Science           TerranBeaty
# 17      18.0                     R        Science      TannerFitzsimons
# 18      19.0                  Java        Science            DarickHess
# 19      20.0       History of Arts           Arts       CarolineKnuesel
# 20      21.0              Painting           Arts         KaterinaYoung
# 21      22.0             Sculpture           Arts        RobertAivazian
# 22      23.0            Musicology           Arts          MadisonBatan
# 23      24.0               Theater           Arts        ErnestStoyanov
# 24      25.0            Literature           Arts           DanielBland
# 25      26.0            Basketball          Sport       KatherineDibari
# 26      27.0            Volleyball          Sport         KaitlinDelude
# 27      28.0              Football          Sport   CortneeKinderknecht
# 28      29.0                 Tenis          Sport           KeeganPrice
# 29      30.0              Swimming          Sport        MikaylaRussell
# 30      31.0            Gymnastics          Sport         MaxwellRomkee
#
#     FirstName_y
# 0            32
# 1            24
# 2            35
# 3            17
# 4            10
# 5            12
# 6            13
# 7            22
# 8            12
# 9            34
# 10           37
# 11           23
# 12           24
# 13           37
# 14           29
# 15           23
# 16           22
# 17           32
# 18           16
# 19           31
# 20           31
# 21           23
# 22           28
# 23           26
# 24           37
# 25            0
# 26           35
# 27            0
# 28           17
# 29           18
# 30           21

# %% [markdown]
# ###  j.	תייצרו Data Frame המראה את התלמידים, מס' הקורסים שהם לוקחים,הממוצע של הציונים לפי יחידה (מחלקה) והממוצע הכוללת שלהם.

# %%
j=pd.merge(Students,Classrooms,how='outer',on='StudentId')
j=pd.merge(j, Courses, how='outer',on= 'CourseId')
df_cnt_crs= j.groupby(['StudentId','FirstName','LastName']).CourseId.nunique()

df_j =df_cnt_crs.reset_index()
df_j.columns=['StudentId','FirstName','LastName','Count courses']

df_English = j[j['DepartmentID']==1]
df_Mean_English= df_English.groupby(['StudentId'])['degree'].mean().reset_index()
df_Mean_English.columns=['StudentId','EnglishDegree']
df_j=pd.merge(df_j,df_Mean_English,how='outer', on='StudentId')

df_Arts = j[j['DepartmentID']==3]
df_Mean_Arts= df_Arts.groupby(['StudentId'])['degree'].mean().reset_index()
df_Mean_Arts.columns=['StudentId','ArtsDegree']
df_j=pd.merge(df_j,df_Mean_Arts,how='outer', on='StudentId')

df_Science = j[j['DepartmentID']==2]
df_Mean_Science= df_Science.groupby(['StudentId'])['degree'].mean().reset_index()
df_Mean_Science.columns=['StudentId','ScienceDegree']
df_j=pd.merge(df_j,df_Mean_Science,how='outer', on='StudentId')

df_Sport = j[j['DepartmentID']==4]
df_Mean_Sport= df_Sport.groupby(['StudentId'])['degree'].mean().reset_index()
df_Mean_Sport.columns=['StudentId','SportDegree']
df_j=pd.merge(df_j,df_Mean_Sport,how='outer', on='StudentId')


df_Mean_General = j.groupby(['StudentId'])['degree'].mean().reset_index()
df_Mean_General.columns=['StudentId','GeneralDegree']
df_j=pd.merge(df_j,df_Mean_General,how='outer', on='StudentId')
df_j
# Out:
#      StudentId    FirstName   LastName  Count courses  EnglishDegree  \
# 0          1.0   Alexandria     Heller              4            NaN
# 1          2.0       Cassie      Liska              5            NaN
# 2          3.0       Hayley      Frank              3      83.972245
# 3          4.0      Maxwell      Kotch              3      70.929801
# 4          5.0        Dylan      Boehm              3            NaN
# ..         ...          ...        ...            ...            ...
# 275      276.0        Dylan  Bannister              3            NaN
# 276      277.0        Bryan     Medina              6            NaN
# 277      278.0       Sydney       Blas              3            NaN
# 278      279.0     Samantha     Berend              1            NaN
# 279      280.0      Matthew    Mcgrath              4            NaN
#
#      ArtsDegree  ScienceDegree  SportDegree  GeneralDegree
# 0     86.677535      79.557508          NaN      81.337515
# 1     79.542738      78.867115          NaN      79.137364
# 2           NaN      76.204427          NaN      78.793700
# 3     69.356144      74.157066          NaN      71.481003
# 4     64.494845     100.000000    65.661106      76.718650
# ..          ...            ...          ...            ...
# 275         NaN      76.784735          NaN      76.784735
# 276   78.849330      81.298837          NaN      80.482335
# 277         NaN      72.578017    76.749775      75.359189
# 278         NaN            NaN          NaN            NaN
# 279   77.237998      75.696576          NaN      76.621429
#
# [280 rows x 9 columns]
